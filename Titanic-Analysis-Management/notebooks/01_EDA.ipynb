# %%
# Drive接続
from google.colab import drive
drive.mount('/content/drive')

# プロジェクトのルートパスを設定
PROJECT_PATH = "/content/drive/MyDrive/Titanic-Analysis-Management"
# !ls "$PROJECT_PATH"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# data  kaggle.json  notebooks  reports  utils

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b00694c-a7f2-4f4e-a313-bea5a406d6e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b00694c-a7f2-4f4e-a313-bea5a406d6e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 1) Kaggle API をセット（アップロード名が "kaggle (1).json" なのでそれを使う）
# !mkdir -p ~/.kaggle
# !cp "kaggle (1).json" ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# 動作テスト：コンペ一覧が出れば認証成功
# !kaggle competitions list | head
# Out:
# ref                                                                                 deadline             category                reward  teamCount  userHasEntered
# ----------------------------------------------------------------------------------  -------------------  ---------------  -------------  ---------  --------------
# https://www.kaggle.com/competitions/arc-prize-2025                                  2025-11-03 23:59:00  Featured         1,000,000 Usd       1473           False
# https://www.kaggle.com/competitions/hull-tactical-market-prediction                 2025-12-15 23:59:00  Featured           100,000 Usd       1702           False
# https://www.kaggle.com/competitions/csiro-biomass                                   2026-01-28 23:59:00  Research            75,000 Usd        509           False
# https://www.kaggle.com/competitions/recodai-luc-scientific-image-forgery-detection  2026-01-15 23:59:00  Research            55,000 Usd        298           False
# ...

# %%
# 2) Titanic データを取得（作業ディレクトリに保存）
# !mkdir -p ./data
# !kaggle competitions download -c titanic -p ./data
# !unzip -o ./data/titanic.zip -d ./data > /dev/null
# !ls -l ./data   # train.csv / test.csv / gender_submission.csv が見えればOK
# Out:
# titanic.zip: Skipping, found more recently modified local copy (use --force to force download)
# total 126
# -rw------- 1 root root  3258 Dec 11  2019 gender_submission.csv
# -rw------- 1 root root 28629 Dec 11  2019 test.csv
# -rw------- 1 root root 34877 Dec 11  2019 titanic.zip
# -rw------- 1 root root 61194 Dec 11  2019 train.csv

# %%
# 3) 読み込みチェック（任意）
import pandas as pd
train = pd.read_csv('./data/train.csv')
test  = pd.read_csv('./data/test.csv')
train.head(), train.shape, test.shape
# Out:
# (   PassengerId  Survived  Pclass  \
#  0            1         0       3
#  1            2         1       1
#  2            3         1       3
#  3            4         1       1
#  4            5         0       3
#
#                                                  Name     Sex   Age  SibSp  \
#  0                            Braund, Mr. Owen Harris    male  22.0      1
#  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                             Heikkinen, Miss. Laina  female  26.0      0
#  3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#  4                           Allen, Mr. William Henry    male  35.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
#  0      0         A/5 21171   7.2500   NaN        S
#  1      0          PC 17599  71.2833   C85        C
#  2      0  STON/O2. 3101282   7.9250   NaN        S
#  3      0            113803  53.1000  C123        S
# ...
